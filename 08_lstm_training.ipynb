# %% [markdown]
# # Model Training: LSTM (Long Short-Term Memory)
# ## Stanford TECH 27 Final Project - Notebook 08
#
# This notebook trains an LSTM model for SOC estimation using the sequential data prepared in notebooks 04 and 05.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, callbacks, optimizers
import warnings
import pickle
from pathlib import Path
import time

warnings.filterwarnings('ignore')

plt.style.use('default')
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 10

print("Libraries imported successfully!")
print(f"TensorFlow version: {tf.__version__}")
print(f"GPU available: {len(tf.config.list_physical_devices('GPU')) > 0}")
if len(tf.config.list_physical_devices('GPU')) > 0:
    print(f"GPU devices: {tf.config.list_physical_devices('GPU')}")
# Out:
# Libraries imported successfully!
# TensorFlow version: 2.20.0
# GPU available: False

# %% [markdown]
# ## Load LSTM Sequential Data
#
# Load the LSTM sequential datasets from notebook 05.

# %%
# Load LSTM sequential data from notebook 05_final_processing.ipynb
OUTPUT_DIR = Path('processed_data')
lstm_datasets_path = OUTPUT_DIR / 'final_lstm_ml_datasets.pkl'

if lstm_datasets_path.exists():
    print(f"Loading LSTM sequential datasets from {lstm_datasets_path}...")
    with open(lstm_datasets_path, 'rb') as f:
        lstm_datasets = pickle.load(f)
    
    # Extract the full datasets
    X_train_full = lstm_datasets['X_train']
    X_val_full = lstm_datasets['X_val']
    X_test_full = lstm_datasets['X_test']
    y_train = lstm_datasets['y_train']
    y_val = lstm_datasets['y_val']
    y_test = lstm_datasets['y_test']
    
    # Get all feature names
    all_feature_names = lstm_datasets.get('feature_names', 
                                          [f'feature_{i}' for i in range(X_train_full.shape[2])])
    
    print(f"✅ Successfully loaded LSTM datasets from notebook 5")
    print(f"Full dataset shapes:")
    print(f"   Training:   X={X_train_full.shape}, y={y_train.shape}")
    print(f"   Validation: X={X_val_full.shape}, y={y_val.shape}")
    print(f"   Test:       X={X_test_full.shape}, y={y_test.shape}")
    print(f"\nSequence length: {X_train_full.shape[1]} timesteps")
    print(f"Number of features: {X_train_full.shape[2]}")
    
else:
    print(f"❌ Error: Could not find {lstm_datasets_path}")
    print("Please run notebook 05_final_processing.ipynb first to generate the LSTM datasets.")
    raise FileNotFoundError(f"Dataset file not found: {lstm_datasets_path}")
# Out:
# Loading LSTM sequential datasets from processed_data/final_lstm_ml_datasets.pkl...
# ✅ Successfully loaded LSTM datasets from notebook 5
# Full dataset shapes:
#    Training:   X=(326521, 20, 45), y=(326521,)
#    Validation: X=(101551, 20, 45), y=(101551,)
#    Test:       X=(113381, 20, 45), y=(113381,)
#
# Sequence length: 20 timesteps
# Number of features: 45

# %% [markdown]
# ## Filter Features
#
# Filter the dataset to use only the realistic features available from V, I, T measurements.

# %%
# Define the specific features to use (same as in notebooks 06 and 07)
features = [
    # Direct measurements
    'voltage', 'current', 'temperature',
    'Current_load', 'Voltage_load',
    
    # Physics-based calculations from V&I
    'power',
    'abs_current',
    'voltage_current_ratio',
    'energy',
    
    # Time derivatives and changes
    'voltage_change',
    'current_change',
    'power_change',
    'temperature_change',
    
    # Rolling statistics
    'voltage_rolling_mean_5', 'voltage_rolling_mean_10',
    'voltage_rolling_std_5', 'voltage_rolling_std_10',
    'current_rolling_mean_5', 'current_rolling_mean_10',
    'current_rolling_std_5', 'current_rolling_std_10',
    
    # Lagged features
    'voltage_lag_1',
    'current_lag_1',
    
    # Cumulative features
    'cumulative_energy',
]

# Find which features are available in the dataset
available_realistic = [f for f in features if f in all_feature_names]
realistic_indices = [all_feature_names.index(f) for f in available_realistic]

print(f"\nFeature Selection Summary:")
print(f"   Total features in dataset: {len(all_feature_names)}")
print(f"   Realistic features requested: {len(features)}")
print(f"   Realistic features available: {len(available_realistic)}")

print(f"\nUsing {len(available_realistic)} features:")
for i, feat in enumerate(available_realistic, 1):
    print(f"{i:3d}. {feat}")
# Out:
# Feature Selection Summary:
#    Total features in dataset: 45
#    Realistic features requested: 24
#    Realistic features available: 24
#
# Using 24 features:
#   1. voltage
#   2. current
#   3. temperature
#   4. Current_load
#   5. Voltage_load
#   6. power
#   7. abs_current
#   8. voltage_current_ratio
#   9. energy
#  10. voltage_change
#  11. current_change
#  12. power_change
#  13. temperature_change
#  14. voltage_rolling_mean_5
#  15. voltage_rolling_mean_10
#  16. voltage_rolling_std_5
#  17. voltage_rolling_std_10
#  18. current_rolling_mean_5
#  19. current_rolling_mean_10
#  20. current_rolling_std_5
#  21. current_rolling_std_10
#  22. voltage_lag_1
#  23. current_lag_1
#  24. cumulative_energy

# %% [markdown]
# ## Create Filtered Datasets

# %%
# Create filtered datasets with only selected features
X_train = X_train_full[:, :, realistic_indices]
X_val = X_val_full[:, :, realistic_indices]
X_test = X_test_full[:, :, realistic_indices]

print(f"\nFiltered dataset shapes:")
print(f"   Training:   X={X_train.shape}, y={y_train.shape}")
print(f"   Validation: X={X_val.shape}, y={y_val.shape}")
print(f"   Test:       X={X_test.shape}, y={y_test.shape}")
print(f"\nFeature reduction: {X_train_full.shape[2]} → {X_train.shape[2]} features")
print(f"Sequence length: {X_train.shape[1]} timesteps")
# Out:
# Filtered dataset shapes:
#    Training:   X=(326521, 20, 24), y=(326521,)
#    Validation: X=(101551, 20, 24), y=(101551,)
#    Test:       X=(113381, 20, 24), y=(113381,)
#
# Feature reduction: 45 → 24 features
# Sequence length: 20 timesteps

# %% [markdown]
# ## Model Evaluation Functions

# %%
def evaluate_model(y_true, y_pred, model_name):
    """Evaluate model performance with multiple metrics."""
    mse = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    
    # Convert to percentage for SOC
    rmse_percent = rmse * 100
    mae_percent = mae * 100
    
    print(f"\n{model_name} Performance:")
    print(f"  R² Score: {r2:.6f}")
    print(f"  RMSE: {rmse:.6f} ({rmse_percent:.3f}% SOC)")
    print(f"  MAE: {mae:.6f} ({mae_percent:.3f}% SOC)")
    
    return {'mse': mse, 'rmse': rmse, 'mae': mae, 'r2': r2,
            'rmse_percent': rmse_percent, 'mae_percent': mae_percent}

def plot_predictions(y_true, y_pred, model_name, dataset_name=''):
    """Plot predicted vs actual values."""
    plt.figure(figsize=(8, 6))
    
    # Sample for visualization if too many points
    if len(y_true) > 10000:
        sample_idx = np.random.choice(len(y_true), 10000, replace=False)
        y_true_sample = y_true[sample_idx]
        y_pred_sample = y_pred[sample_idx]
    else:
        y_true_sample = y_true
        y_pred_sample = y_pred
    
    plt.scatter(y_true_sample * 100, y_pred_sample * 100, alpha=0.6, s=1)
    
    # Plot perfect prediction line
    plt.plot([0, 100], [0, 100], 'r--', lw=2, label='Perfect Prediction')
    
    plt.xlabel('Actual SOC (%)')
    plt.ylabel('Predicted SOC (%)')
    plt.title(f'{model_name} - Predicted vs Actual {dataset_name}')
    plt.legend()
    plt.grid(True, alpha=0.3)
    
    # Add R² score to plot
    r2 = r2_score(y_true, y_pred)
    rmse_percent = np.sqrt(mean_squared_error(y_true, y_pred)) * 100
    plt.text(0.05, 0.95, f'R² = {r2:.4f}\nRMSE = {rmse_percent:.2f}%', 
             transform=plt.gca().transAxes,
             bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.8),
             verticalalignment='top')
    
    plt.tight_layout()
    plt.show()

def plot_training_history(history):
    """Plot training and validation loss over epochs."""
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    
    # Loss plot
    axes[0].plot(history.history['loss'], label='Training Loss')
    axes[0].plot(history.history['val_loss'], label='Validation Loss')
    axes[0].set_xlabel('Epoch')
    axes[0].set_ylabel('Loss (MSE)')
    axes[0].set_title('Training and Validation Loss')
    axes[0].legend()
    axes[0].grid(True, alpha=0.3)
    
    # MAE plot
    if 'mae' in history.history:
        axes[1].plot(history.history['mae'], label='Training MAE')
        axes[1].plot(history.history['val_mae'], label='Validation MAE')
        axes[1].set_xlabel('Epoch')
        axes[1].set_ylabel('MAE')
        axes[1].set_title('Training and Validation MAE')
        axes[1].legend()
        axes[1].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Build LSTM Model

# %%
def build_lstm_model(sequence_length, n_features, lstm_units=[32, 16], 
                    dropout_rate=0.2, l2_reg=0.001):
    """
    Build an LSTM model for SOC estimation.
    
    Args:
        sequence_length: Length of input sequences
        n_features: Number of features
        lstm_units: List of LSTM unit sizes
        dropout_rate: Dropout rate for regularization
        l2_reg: L2 regularization strength
    """
    from tensorflow.keras import regularizers
    
    model = models.Sequential([
        # Input layer
        layers.Input(shape=(sequence_length, n_features)),
        
        # Masking layer for padded sequences if needed
        layers.Masking(mask_value=0.0),
        
        # First LSTM layer
        layers.LSTM(lstm_units[0], 
                   return_sequences=True,
                   dropout=dropout_rate,
                   recurrent_dropout=0),
        layers.BatchNormalization(),
        
        # Second LSTM layer
        layers.LSTM(lstm_units[1],
                   dropout=dropout_rate,
                   recurrent_dropout=0),
        layers.BatchNormalization(),
        
        # Dense layer
        layers.Dense(16, activation='relu',
                    kernel_regularizer=regularizers.l2(l2_reg)),
        layers.Dropout(dropout_rate),
        
        # Output layer
        layers.Dense(1, activation='sigmoid')  # Sigmoid for SOC in range [0, 1]
    ])
    
    return model

# Build the model
sequence_length = X_train.shape[1]
n_features = X_train.shape[2]

print("Building LSTM model...")
lstm_model = build_lstm_model(
    sequence_length=sequence_length,
    n_features=n_features,
    lstm_units=[32, 16],
    dropout_rate=0.2,
    l2_reg=0.001
)

# Compile the model
lstm_model.compile(
    optimizer=optimizers.Adam(learning_rate=0.0001),
    loss='mse',
    metrics=['mae']
)

# Display model architecture
print("\nModel Architecture:")
lstm_model.summary()

# Count parameters
total_params = lstm_model.count_params()
print(f"\nTotal parameters: {total_params:,}")
# Out:
# Building LSTM model...
#
# Model Architecture:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ masking (Masking)               │ (None, 20, 24)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 20, 32)         │         7,296 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 20, 32)         │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 16)             │         3,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 16)             │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,913 (42.63 KB)
#  Trainable params: 10,817 (42.25 KB)
#  Non-trainable params: 96 (384.00 B)
# Total parameters: 10,913

# %% [markdown]
# ## Train the Model

# %%
print("="*60)
print("TRAINING LSTM")
print("="*60)

# Define callbacks
early_stopping = callbacks.EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=7,
    min_lr=1e-8,
    verbose=1
)

model_checkpoint = callbacks.ModelCheckpoint(
    OUTPUT_DIR / 'best_lstm_model.keras',
    monitor='val_loss',
    save_best_only=True,
    verbose=1
)

# Training parameters
batch_size = 512
epochs = 150

print(f"\nTraining parameters:")
print(f"   Batch size: {batch_size}")
print(f"   Max epochs: {epochs}")
print(f"   Early stopping patience: 15")
print(f"   Learning rate: 0.0001")
print(f"   Dropout rate: 0.2")
print(f"   L2 regularization: 0.001")
print(f"   LSTM units: [32, 16]")

# Train the model
print(f"\nStarting training...")
start_time = time.time()

history = lstm_model.fit(
    X_train, y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    callbacks=[early_stopping, reduce_lr, model_checkpoint],
    verbose=1
)

training_time = time.time() - start_time
print(f"\nTraining completed in {training_time:.2f} seconds ({training_time/60:.2f} minutes)")
print(f"Best epoch: {np.argmin(history.history['val_loss']) + 1}")
print(f"Best validation loss: {np.min(history.history['val_loss']):.6f}")
# Out:
# ============================================================
# TRAINING LSTM
# ============================================================
#
# Training parameters:
#    Batch size: 512
#    Max epochs: 150
#    Early stopping patience: 15
#    Learning rate: 0.0001
#    Dropout rate: 0.2
#    L2 regularization: 0.001
#    LSTM units: [32, 16]
#
# Starting training...
# Epoch 1/150
# 636/638 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0858 - mae: 0.2161
# Epoch 1: val_loss improved from None to 0.05262, saving model to processed_data/best_lstm_model.keras
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - loss: 0.0764 - mae: 0.2034 - val_loss: 0.0526 - val_mae: 0.1667 - learning_rate: 1.0000e-04
# Epoch 2/150
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0626 - mae: 0.1861
# Epoch 2: val_loss improved from 0.05262 to 0.04711, saving model to processed_data/best_lstm_model.keras
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 19s 29ms/step - loss: 0.0606 - mae: 0.1840 - val_loss: 0.0471 - val_mae: 0.1617 - learning_rate: 1.0000e-04
# Epoch 3/150
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0553 - mae: 0.1780
# Epoch 3: val_loss improved from 0.04711 to 0.04220, saving model to processed_data/best_lstm_model.keras
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - loss: 0.0537 - mae: 0.1760 - val_loss: 0.0422 - val_mae: 0.1556 - learning_rate: 1.0000e-04
# Epoch 4/150
# 637/638 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0497 - mae: 0.1708
# Epoch 4: val_loss improved from 0.04220 to 0.03791, saving model to processed_data/best_lstm_model.keras
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 18s 28ms/step - loss: 0.0485 - mae: 0.1691 - val_loss: 0.0379 - val_mae: 0.1492 - learning_rate: 1.0000e-04
# Epoch 5/150
# 637/638 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0451 - mae: 0.1638
# Epoch 5: val_loss improved from 0.03791 to 0.03470, saving model to processed_data/best_lstm_model.keras
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - loss: 0.0439 - mae: 0.1615 - val_loss: 0.0347 - val_mae: 0.1448 - learning_rate: 1.0000e-04
# Epoch 6/150
# 636/638 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0404 - mae: 0.1550
# Epoch 6: val_loss improved from 0.03470 to 0.03220, saving model to processed_data/best_lstm_model.keras
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 15s 24ms/step - loss: 0.0392 - mae: 0.1523 - val_loss: 0.0322 - val_mae: 0.1396 - learning_rate: 1.0000e-04
# Epoch 7/150
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0360 - mae: 0.1447
# Epoch 7: val_loss improved from 0.03220 to 0.03084, saving model to processed_data/best_lstm_model.keras
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - loss: 0.0350 - mae: 0.1425 - val_loss: 0.0308 - val_mae: 0.1360 - learning_rate: 1.0000e-04
# Epoch 8/150
# 637/638 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0326 - mae: 0.1369
# Epoch 8: val_loss improved from 0.03084 to 0.03060, saving model to processed_data/best_lstm_model.keras
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 13s 21ms/step - loss: 0.0320 - mae: 0.1354 - val_loss: 0.0306 - val_mae: 0.1369 - learning_rate: 1.0000e-04
# Epoch 9/150
# 637/638 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0304 - mae: 0.1313
# Epoch 9: val_loss improved from 0.03060 to 0.02997, saving model to processed_data/best_lstm_model.keras
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 15s 23ms/step - loss: 0.0298 - mae: 0.1297 - val_loss: 0.0300 - val_mae: 0.1358 - learning_rate: 1.0000e-04
# Epoch 10/150
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0283 - mae: 0.1260
# Epoch 10: val_loss improved from 0.02997 to 0.02935, saving model to processed_data/best_lstm_model.keras
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 16s 25ms/step - loss: 0.0280 - mae: 0.1252 - val_loss: 0.0294 - val_mae: 0.1343 - learning_rate: 1.0000e-04
# Epoch 11/150
# 636/638 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0270 - mae: 0.1225
# Epoch 11: val_loss did not improve from 0.02935
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 14s 22ms/step - loss: 0.0267 - mae: 0.1219 - val_loss: 0.0300 - val_mae: 0.1372 - learning_rate: 1.0000e-04
# Epoch 12/150
# 637/638 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0256 - mae: 0.1192
# Epoch 12: val_loss did not improve from 0.02935
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 15s 23ms/step - loss: 0.0254 - mae: 0.1187 - val_loss: 0.0294 - val_mae: 0.1354 - learning_rate: 1.0000e-04
# Epoch 13/150
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0247 - mae: 0.1167
# Epoch 13: val_loss improved from 0.02935 to 0.02847, saving model to processed_data/best_lstm_model.keras
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 15s 24ms/step - loss: 0.0244 - mae: 0.1160 - val_loss: 0.0285 - val_mae: 0.1324 - learning_rate: 1.0000e-04
# Epoch 14/150
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0237 - mae: 0.1140
# Epoch 14: val_loss did not improve from 0.02847
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 14s 22ms/step - loss: 0.0234 - mae: 0.1135 - val_loss: 0.0286 - val_mae: 0.1331 - learning_rate: 1.0000e-04
# Epoch 15/150
# 637/638 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0229 - mae: 0.1120
# Epoch 15: val_loss improved from 0.02847 to 0.02823, saving model to processed_data/best_lstm_model.keras
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 13s 20ms/step - loss: 0.0226 - mae: 0.1114 - val_loss: 0.0282 - val_mae: 0.1325 - learning_rate: 1.0000e-04
# Epoch 16/150
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0221 - mae: 0.1098
# Epoch 16: val_loss improved from 0.02823 to 0.02732, saving model to processed_data/best_lstm_model.keras
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 15s 24ms/step - loss: 0.0219 - mae: 0.1093 - val_loss: 0.0273 - val_mae: 0.1288 - learning_rate: 1.0000e-04
# Epoch 17/150
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0212 - mae: 0.1076
# Epoch 17: val_loss did not improve from 0.02732
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 17s 26ms/step - loss: 0.0211 - mae: 0.1073 - val_loss: 0.0289 - val_mae: 0.1324 - learning_rate: 1.0000e-04
# Epoch 18/150
# 636/638 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0206 - mae: 0.1057
# Epoch 18: val_loss improved from 0.02732 to 0.02648, saving model to processed_data/best_lstm_model.keras
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 16s 25ms/step - loss: 0.0203 - mae: 0.1052 - val_loss: 0.0265 - val_mae: 0.1259 - learning_rate: 1.0000e-04
# Epoch 19/150
# 636/638 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0196 - mae: 0.1033
# Epoch 19: val_loss did not improve from 0.02648
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 15s 24ms/step - loss: 0.0194 - mae: 0.1026 - val_loss: 0.0277 - val_mae: 0.1302 - learning_rate: 1.0000e-04
# Epoch 20/150
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0188 - mae: 0.1012
# Epoch 20: val_loss did not improve from 0.02648
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 16s 25ms/step - loss: 0.0186 - mae: 0.1005 - val_loss: 0.0290 - val_mae: 0.1332 - learning_rate: 1.0000e-04
# Epoch 21/150
# 637/638 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0178 - mae: 0.0985
# Epoch 21: val_loss did not improve from 0.02648
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 15s 24ms/step - loss: 0.0177 - mae: 0.0979 - val_loss: 0.0312 - val_mae: 0.1375 - learning_rate: 1.0000e-04
# Epoch 22/150
# 637/638 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0169 - mae: 0.0955
# Epoch 22: val_loss did not improve from 0.02648
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 17s 27ms/step - loss: 0.0168 - mae: 0.0954 - val_loss: 0.0321 - val_mae: 0.1393 - learning_rate: 1.0000e-04
# Epoch 23/150
# 637/638 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0162 - mae: 0.0934
# Epoch 23: val_loss did not improve from 0.02648
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 16s 25ms/step - loss: 0.0160 - mae: 0.0929 - val_loss: 0.0336 - val_mae: 0.1412 - learning_rate: 1.0000e-04
# Epoch 24/150
# 637/638 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0156 - mae: 0.0916
# Epoch 24: val_loss did not improve from 0.02648
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 15s 24ms/step - loss: 0.0154 - mae: 0.0911 - val_loss: 0.0360 - val_mae: 0.1457 - learning_rate: 1.0000e-04
# Epoch 25/150
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0150 - mae: 0.0900
# Epoch 25: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 25: val_loss did not improve from 0.02648
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 16s 26ms/step - loss: 0.0148 - mae: 0.0894 - val_loss: 0.0430 - val_mae: 0.1580 - learning_rate: 1.0000e-04
# Epoch 26/150
# 637/638 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0144 - mae: 0.0880
# Epoch 26: val_loss did not improve from 0.02648
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 16s 26ms/step - loss: 0.0144 - mae: 0.0879 - val_loss: 0.0416 - val_mae: 0.1551 - learning_rate: 5.0000e-05
# Epoch 27/150
# 636/638 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0143 - mae: 0.0874
# Epoch 27: val_loss did not improve from 0.02648
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 15s 24ms/step - loss: 0.0142 - mae: 0.0873 - val_loss: 0.0419 - val_mae: 0.1555 - learning_rate: 5.0000e-05
# Epoch 28/150
# 637/638 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0140 - mae: 0.0868
# Epoch 28: val_loss did not improve from 0.02648
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 18s 28ms/step - loss: 0.0140 - mae: 0.0867 - val_loss: 0.0425 - val_mae: 0.1570 - learning_rate: 5.0000e-05
# Epoch 29/150
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0139 - mae: 0.0864
# Epoch 29: val_loss did not improve from 0.02648
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 15s 24ms/step - loss: 0.0138 - mae: 0.0861 - val_loss: 0.0430 - val_mae: 0.1572 - learning_rate: 5.0000e-05
# Epoch 30/150
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0138 - mae: 0.0858
# Epoch 30: val_loss did not improve from 0.02648
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 15s 23ms/step - loss: 0.0137 - mae: 0.0857 - val_loss: 0.0442 - val_mae: 0.1596 - learning_rate: 5.0000e-05
# Epoch 31/150
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0136 - mae: 0.0852
# Epoch 31: val_loss did not improve from 0.02648
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 16s 25ms/step - loss: 0.0135 - mae: 0.0849 - val_loss: 0.0445 - val_mae: 0.1602 - learning_rate: 5.0000e-05
# Epoch 32/150
# 637/638 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0135 - mae: 0.0847
# Epoch 32: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 32: val_loss did not improve from 0.02648
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 15s 23ms/step - loss: 0.0134 - mae: 0.0846 - val_loss: 0.0458 - val_mae: 0.1623 - learning_rate: 5.0000e-05
# Epoch 33/150
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0133 - mae: 0.0845
# Epoch 33: val_loss did not improve from 0.02648
# 638/638 ━━━━━━━━━━━━━━━━━━━━ 15s 24ms/step - loss: 0.0132 - mae: 0.0841 - val_loss: 0.0466 - val_mae: 0.1641 - learning_rate: 2.5000e-05
# Epoch 33: early stopping
# Restoring model weights from the end of the best epoch: 18.
#
# Training completed in 518.74 seconds (8.65 minutes)
# Best epoch: 18
# Best validation loss: 0.026480

# %%
print("="*60)
print("TRAINING LSTM")
print("="*60)

# Define callbacks
early_stopping = callbacks.EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    verbose=1
)

reduce_lr = callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=5,
    min_lr=1e-7,
    verbose=1
)

model_checkpoint = callbacks.ModelCheckpoint(
    OUTPUT_DIR / 'best_lstm_model.keras',
    monitor='val_loss',
    save_best_only=True,
    verbose=1
)

# Training parameters
batch_size = 256
epochs = 100

print(f"\nTraining parameters:")
print(f"   Batch size: {batch_size}")
print(f"   Max epochs: {epochs}")
print(f"   Early stopping patience: 10")
print(f"   Learning rate: 0.001")
print(f"   Dropout rate: 0.4")
print(f"   Recurrent dropout: 0.2")
print(f"   L2 regularization: 0.01")
print(f"   LSTM units: [64, 32]")

# Train the model
print(f"\nStarting training...")
start_time = time.time()

history = lstm_model.fit(
    X_train, y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    callbacks=[early_stopping, reduce_lr, model_checkpoint],
    verbose=1
)

training_time = time.time() - start_time
print(f"\nTraining completed in {training_time:.2f} seconds ({training_time/60:.2f} minutes)")
print(f"Best epoch: {np.argmin(history.history['val_loss']) + 1}")
print(f"Best validation loss: {np.min(history.history['val_loss']):.6f}")
# Out:
# ============================================================
# TRAINING LSTM
# ============================================================
#
# Training parameters:
#    Batch size: 256
#    Max epochs: 100
#    Early stopping patience: 10
#    Learning rate: 0.001
#    Dropout rate: 0.4
#    Recurrent dropout: 0.2
#    L2 regularization: 0.01
#    LSTM units: [64, 32]
#
# Starting training...
# Epoch 1/100
# 1273/1276 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0200 - mae: 0.1047
# Epoch 1: val_loss improved from None to 0.02553, saving model to processed_data/best_lstm_model.keras
# 1276/1276 ━━━━━━━━━━━━━━━━━━━━ 17s 13ms/step - loss: 0.0198 - mae: 0.1040 - val_loss: 0.0255 - val_mae: 0.1234 - learning_rate: 2.5000e-05
# Epoch 2/100
# 1273/1276 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0195 - mae: 0.1032
# Epoch 2: val_loss did not improve from 0.02553
# 1276/1276 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - loss: 0.0195 - mae: 0.1032 - val_loss: 0.0266 - val_mae: 0.1264 - learning_rate: 2.5000e-05
# Epoch 3/100
# 1274/1276 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0193 - mae: 0.1026
# Epoch 3: val_loss did not improve from 0.02553
# 1276/1276 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - loss: 0.0192 - mae: 0.1024 - val_loss: 0.0261 - val_mae: 0.1256 - learning_rate: 2.5000e-05
# Epoch 4/100
# 1272/1276 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0191 - mae: 0.1019
# Epoch 4: val_loss did not improve from 0.02553
# 1276/1276 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - loss: 0.0189 - mae: 0.1015 - val_loss: 0.0271 - val_mae: 0.1283 - learning_rate: 2.5000e-05
# Epoch 5/100
# 1275/1276 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0187 - mae: 0.1010
# Epoch 5: val_loss did not improve from 0.02553
# 1276/1276 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - loss: 0.0186 - mae: 0.1008 - val_loss: 0.0271 - val_mae: 0.1283 - learning_rate: 2.5000e-05
# Epoch 6/100
# 1275/1276 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0185 - mae: 0.1003
# Epoch 6: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 6: val_loss did not improve from 0.02553
# 1276/1276 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - loss: 0.0184 - mae: 0.1001 - val_loss: 0.0276 - val_mae: 0.1302 - learning_rate: 2.5000e-05
# Epoch 7/100
# 1274/1276 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0180 - mae: 0.0992
# Epoch 7: val_loss did not improve from 0.02553
# 1276/1276 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - loss: 0.0181 - mae: 0.0992 - val_loss: 0.0271 - val_mae: 0.1286 - learning_rate: 1.2500e-05
# Epoch 8/100
# 1275/1276 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0178 - mae: 0.0985
# Epoch 8: val_loss did not improve from 0.02553
# 1276/1276 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - loss: 0.0179 - mae: 0.0987 - val_loss: 0.0271 - val_mae: 0.1288 - learning_rate: 1.2500e-05
# Epoch 9/100
# 1273/1276 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0179 - mae: 0.0987
# Epoch 9: val_loss did not improve from 0.02553
# 1276/1276 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - loss: 0.0178 - mae: 0.0985 - val_loss: 0.0273 - val_mae: 0.1294 - learning_rate: 1.2500e-05
# Epoch 10/100
# 1273/1276 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0177 - mae: 0.0981
# Epoch 10: val_loss did not improve from 0.02553
# 1276/1276 ━━━━━━━━━━━━━━━━━━━━ 16s 12ms/step - loss: 0.0177 - mae: 0.0981 - val_loss: 0.0272 - val_mae: 0.1293 - learning_rate: 1.2500e-05
# Epoch 11/100
# 1276/1276 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0175 - mae: 0.0978
# Epoch 11: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
#
# Epoch 11: val_loss did not improve from 0.02553
# 1276/1276 ━━━━━━━━━━━━━━━━━━━━ 15s 12ms/step - loss: 0.0176 - mae: 0.0978 - val_loss: 0.0284 - val_mae: 0.1321 - learning_rate: 1.2500e-05
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.
#
# Training completed in 170.49 seconds (2.84 minutes)
# Best epoch: 1
# Best validation loss: 0.025532

# %% [markdown]
# ## Visualize Training History

# %%
# Plot training history
plot_training_history(history)

# Additional training metrics
print("\nTraining Summary:")
print(f"   Final training loss: {history.history['loss'][-1]:.6f}")
print(f"   Final validation loss: {history.history['val_loss'][-1]:.6f}")
print(f"   Final training MAE: {history.history['mae'][-1]:.6f}")
print(f"   Final validation MAE: {history.history['val_mae'][-1]:.6f}")
print(f"   Total epochs trained: {len(history.history['loss'])}")
# Out:
# Training Summary:
#    Final training loss: 0.017559
#    Final validation loss: 0.028419
#    Final training MAE: 0.097770
#    Final validation MAE: 0.132137
#    Total epochs trained: 11

# %% [markdown]
# ## Evaluate Model Performance

# %%
# Make predictions
print("Making predictions...")
lstm_train_pred = lstm_model.predict(X_train, batch_size=batch_size, verbose=0).flatten()
lstm_val_pred = lstm_model.predict(X_val, batch_size=batch_size, verbose=0).flatten()
lstm_test_pred = lstm_model.predict(X_test, batch_size=batch_size, verbose=0).flatten()

# Evaluate performance
lstm_train_metrics = evaluate_model(y_train, lstm_train_pred, "LSTM (Training)")
lstm_val_metrics = evaluate_model(y_val, lstm_val_pred, "LSTM (Validation)")
lstm_test_metrics = evaluate_model(y_test, lstm_test_pred, "LSTM (Test)")

print("\nLSTM evaluation completed.")
# Out:
# Making predictions...
#
# LSTM (Training) Performance:
#   R² Score: 0.363190
#   RMSE: 0.181511 (18.151% SOC)
#   MAE: 0.142175 (14.217% SOC)
#
# LSTM (Validation) Performance:
#   R² Score: 0.455724
#   RMSE: 0.158462 (15.846% SOC)
#   MAE: 0.123421 (12.342% SOC)
#
# LSTM (Test) Performance:
#   R² Score: 0.322336
#   RMSE: 0.182830 (18.283% SOC)
#   MAE: 0.145510 (14.551% SOC)
#
# LSTM evaluation completed.

# %% [markdown]
# ## Visualize Predictions

# %%
# Visualize predictions on validation set
plot_predictions(y_val, lstm_val_pred, "LSTM", "(Validation Set)")

# Visualize predictions on test set
plot_predictions(y_test, lstm_test_pred, "LSTM", "(Test Set)")

# %%
# Save the model
model_path = OUTPUT_DIR / 'final_lstm_model.keras'  # Save in processed_data
lstm_model.save(model_path)
print(f"✅ Model saved to {model_path}")

# Save results and metrics
results = {
    'model_type': 'LSTM',
    'sequence_length': sequence_length,
    'n_features': n_features,
    'feature_names': available_realistic,
    'total_parameters': total_params,
    'training_time': training_time,
    'epochs_trained': len(history.history['loss']),
    'metrics': {
        'train': lstm_train_metrics,
        'val': lstm_val_metrics,
        'test': lstm_test_metrics
    },
    'history': history.history
}

results_path = OUTPUT_DIR / 'lstm_results.pkl'
with open(results_path, 'wb') as f:
    pickle.dump(results, f)
print(f"✅ Results saved to {results_path}")
# Out:
# ✅ Model saved to processed_data/final_lstm_model.keras
# ✅ Results saved to processed_data/lstm_results.pkl
#
# ✨ LSTM training notebook completed successfully!

# %%
def plot_residuals(y_true, y_pred, model_name, dataset_name=''):
    """Plot residuals to check for patterns."""
    residuals = (y_true - y_pred) * 100  # Convert to percentage
    
    fig, axes = plt.subplots(1, 2, figsize=(15, 6))
    
    # Sample for visualization if too many points
    if len(y_true) > 10000:
        sample_idx = np.random.choice(len(y_true), 10000, replace=False)
        y_pred_sample = y_pred[sample_idx]
        residuals_sample = residuals[sample_idx]
    else:
        y_pred_sample = y_pred
        residuals_sample = residuals
    
    # Residuals vs Predicted
    axes[0].scatter(y_pred_sample * 100, residuals_sample, alpha=0.6, s=1)
    axes[0].axhline(y=0, color='r', linestyle='--')
    axes[0].set_xlabel('Predicted SOC (%)')
    axes[0].set_ylabel('Residuals (% SOC)')
    axes[0].set_title(f'{model_name} - Residuals vs Predicted {dataset_name}')
    axes[0].grid(True, alpha=0.3)
    
    # Residuals histogram
    axes[1].hist(residuals, bins=50, alpha=0.7, edgecolor='black')
    axes[1].set_xlabel('Residuals (% SOC)')
    axes[1].set_ylabel('Frequency')
    axes[1].set_title(f'{model_name} - Residuals Distribution {dataset_name}')
    axes[1].grid(True, alpha=0.3)
    
    # Add statistics
    mean_res = np.mean(residuals)
    std_res = np.std(residuals)
    axes[1].axvline(x=mean_res, color='red', linestyle='--', label=f'Mean: {mean_res:.3f}%')
    axes[1].axvline(x=mean_res + std_res, color='orange', linestyle=':', label=f'±1σ: {std_res:.3f}%')
    axes[1].axvline(x=mean_res - std_res, color='orange', linestyle=':')
    axes[1].legend()
    
    plt.tight_layout()
    plt.show()

# Plot residuals for validation and test sets
plot_residuals(y_val, lstm_val_pred, "LSTM", "(Validation Set)")
plot_residuals(y_test, lstm_test_pred, "LSTM", "(Test Set)")

# %% [markdown]
# ## Compare with Baseline Models
#
# Load and compare with results from notebooks 06 and 07.

# %%
# Baseline results from notebooks 06 and 07
baseline_results = {
    'Linear Regression': {'Test_R2': 0.208879, 'Test_RMSE_%': 19.756},
    'Random Forest': {'Test_R2': 0.917825, 'Test_RMSE_%': 6.367},
    'XGBoost': {'Test_R2': 0.904824, 'Test_RMSE_%': 6.852},
    '1D CNN': {'Test_R2': 0.864226, 'Test_RMSE_%': 8.182}
}

# Add LSTM results
lstm_results = {
    'LSTM': {
        'Training_R2': lstm_train_metrics['r2'],
        'Training_RMSE_%': lstm_train_metrics['rmse_percent'],
        'Validation_R2': lstm_val_metrics['r2'],
        'Validation_RMSE_%': lstm_val_metrics['rmse_percent'],
        'Test_R2': lstm_test_metrics['r2'],
        'Test_RMSE_%': lstm_test_metrics['rmse_percent']
    }
}

print("="*80)
print("MODEL PERFORMANCE COMPARISON")
print("="*80)
print(f"\nUsing {n_features} features with {sequence_length} timesteps\n")
print(f"{'Model':<20} {'Train R²':>10} {'Val R²':>10} {'Test R²':>10} {'Test RMSE (%)':>15}")
print("-"*75)

# Print baseline results
for model_name, metrics in baseline_results.items():
    print(f"{model_name:<20} {'-':>10} {'-':>10} {metrics['Test_R2']:>10.6f} {metrics['Test_RMSE_%']:>15.3f}")

# Print LSTM results
for model_name, metrics in lstm_results.items():
    print(f"{model_name:<20} {metrics['Training_R2']:>10.6f} {metrics['Validation_R2']:>10.6f} "
          f"{metrics['Test_R2']:>10.6f} {metrics['Test_RMSE_%']:>15.3f}")

# Visualization
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# R² comparison
models = list(baseline_results.keys()) + list(lstm_results.keys())
test_r2 = [baseline_results[m]['Test_R2'] for m in baseline_results.keys()] + \
          [lstm_results[m]['Test_R2'] for m in lstm_results.keys()]
colors = ['blue', 'green', 'orange', 'red', 'purple']

axes[0].bar(models, test_r2, color=colors, alpha=0.7)
axes[0].set_ylabel('R² Score')
axes[0].set_title('Test Set R² Score Comparison (Higher is Better)')
axes[0].grid(True, alpha=0.3)
axes[0].set_ylim([0, 1])
for i, (model, score) in enumerate(zip(models, test_r2)):
    axes[0].text(i, score + 0.01, f'{score:.3f}', ha='center', va='bottom')

# RMSE comparison
test_rmse = [baseline_results[m]['Test_RMSE_%'] for m in baseline_results.keys()] + \
            [lstm_results[m]['Test_RMSE_%'] for m in lstm_results.keys()]

axes[1].bar(models, test_rmse, color=colors, alpha=0.7)
axes[1].set_ylabel('RMSE (% SOC)')
axes[1].set_title('Test Set RMSE Comparison (Lower is Better)')
axes[1].grid(True, alpha=0.3)
for i, (model, rmse) in enumerate(zip(models, test_rmse)):
    axes[1].text(i, rmse + 0.2, f'{rmse:.2f}%', ha='center', va='bottom')

plt.tight_layout()
plt.show()
# Out:
# ================================================================================
# MODEL PERFORMANCE COMPARISON
# ================================================================================
#
# Using 24 features with 20 timesteps
#
# Model                  Train R²     Val R²    Test R²   Test RMSE (%)
# ---------------------------------------------------------------------------
# Linear Regression             -          -   0.208879          19.756
# Random Forest                 -          -   0.917825           6.367
# XGBoost                       -          -   0.904824           6.852
# 1D CNN                        -          -   0.864226           8.182
# LSTM                   0.363190   0.455724   0.322336          18.283

# %% [markdown]
# ## Summary

# %%
print("="*80)
print("LSTM MODEL TRAINING SUMMARY")
print("="*80)

print("\nDataset Configuration:")
print(f"   Total features available: {X_train_full.shape[2]}")
print(f"   Features used: {n_features}")
print(f"   Sequence length: {sequence_length} timesteps")
print(f"   Training sequences: {X_train.shape[0]:,}")
print(f"   Validation sequences: {X_val.shape[0]:,}")
print(f"   Test sequences: {X_test.shape[0]:,}")

print("\nModel Architecture:")
print(f"   Total parameters: {total_params:,}")
print(f"   LSTM layers: 2 (64, 32 units)")
print(f"   Dense layers: 2 (32, 16 units)")
print(f"   Dropout rate: 0.4")
print(f"   Recurrent dropout: 0.2")

print("\nTraining Results:")
print(f"   Epochs trained: {len(history.history['loss'])}")
print(f"   Training time: {training_time/60:.2f} minutes")
print(f"   Best validation loss: {np.min(history.history['val_loss']):.6f}")

print("\nPerformance Summary:")
print(f"   Training R²: {lstm_train_metrics['r2']:.6f}")
print(f"   Validation R²: {lstm_val_metrics['r2']:.6f}")
print(f"   Test R²: {lstm_test_metrics['r2']:.6f}")
print(f"   Test RMSE: {lstm_test_metrics['rmse_percent']:.3f}% SOC")
print(f"   Test MAE: {lstm_test_metrics['mae_percent']:.3f}% SOC")

# Check for overfitting
train_val_gap = lstm_train_metrics['r2'] - lstm_val_metrics['r2']
status = "✅ Good" if train_val_gap < 0.05 else "⚠️ Mild" if train_val_gap < 0.1 else "❌ Severe"
print(f"\nOverfitting Analysis:")
print(f"   Train-Val R² gap: {train_val_gap:.4f} ({status})")
print(f"   Train-Test R² gap: {lstm_train_metrics['r2'] - lstm_test_metrics['r2']:.4f}")

# Compare with best baseline
best_baseline = 'Random Forest'
best_baseline_r2 = baseline_results[best_baseline]['Test_R2']
best_baseline_rmse = baseline_results[best_baseline]['Test_RMSE_%']

print(f"\nComparison with Best Baseline ({best_baseline}):")
print(f"   Baseline Test R²: {best_baseline_r2:.6f}")
print(f"   LSTM Test R²: {lstm_test_metrics['r2']:.6f}")
print(f"   R² Difference: {lstm_test_metrics['r2'] - best_baseline_r2:+.6f}")
print(f"   Baseline Test RMSE: {best_baseline_rmse:.3f}% SOC")
print(f"   LSTM Test RMSE: {lstm_test_metrics['rmse_percent']:.3f}% SOC")
print(f"   RMSE Difference: {lstm_test_metrics['rmse_percent'] - best_baseline_rmse:+.3f}% SOC")

# Compare with CNN
cnn_r2 = baseline_results['1D CNN']['Test_R2']
cnn_rmse = baseline_results['1D CNN']['Test_RMSE_%']

print(f"\nComparison with 1D CNN:")
print(f"   CNN Test R²: {cnn_r2:.6f}")
print(f"   LSTM Test R²: {lstm_test_metrics['r2']:.6f}")
print(f"   R² Difference: {lstm_test_metrics['r2'] - cnn_r2:+.6f}")
print(f"   CNN Test RMSE: {cnn_rmse:.3f}% SOC")
print(f"   LSTM Test RMSE: {lstm_test_metrics['rmse_percent']:.3f}% SOC")
print(f"   RMSE Difference: {lstm_test_metrics['rmse_percent'] - cnn_rmse:+.3f}% SOC")

if lstm_test_metrics['r2'] > best_baseline_r2:
    print(f"\n🎉 LSTM outperforms all baseline models!")
elif lstm_test_metrics['r2'] > cnn_r2:
    print(f"\n✅ LSTM outperforms CNN for sequential modeling!")
else:
    print(f"\n📊 LSTM performance is comparable to baseline models.")
# Out:
# ================================================================================
# LSTM MODEL TRAINING SUMMARY
# ================================================================================
#
# Dataset Configuration:
#    Total features available: 45
#    Features used: 24
#    Sequence length: 20 timesteps
#    Training sequences: 326,521
#    Validation sequences: 101,551
#    Test sequences: 113,381
#
# Model Architecture:
#    Total parameters: 10,913
#    LSTM layers: 2 (64, 32 units)
#    Dense layers: 2 (32, 16 units)
#    Dropout rate: 0.4
#    Recurrent dropout: 0.2
#
# Training Results:
#    Epochs trained: 11
#    Training time: 2.84 minutes
#    Best validation loss: 0.025532
#
# Performance Summary:
#    Training R²: 0.363190
#    Validation R²: 0.455724
#    Test R²: 0.322336
#    Test RMSE: 18.283% SOC
#    Test MAE: 14.551% SOC
#
# Overfitting Analysis:
#    Train-Val R² gap: -0.0925 (✅ Good)
#    Train-Test R² gap: 0.0409
#
# Comparison with Best Baseline (Random Forest):
#    Baseline Test R²: 0.917825
#    LSTM Test R²: 0.322336
#    R² Difference: -0.595489
#    Baseline Test RMSE: 6.367% SOC
#    LSTM Test RMSE: 18.283% SOC
#    RMSE Difference: +11.916% SOC
#
# Comparison with 1D CNN:
#    CNN Test R²: 0.864226
#    LSTM Test R²: 0.322336
#    R² Difference: -0.541890
#    CNN Test RMSE: 8.182% SOC
#    LSTM Test RMSE: 18.283% SOC
#    RMSE Difference: +10.101% SOC
#
# 📊 LSTM performance is comparable to baseline models.

# %% [markdown]
# ## Save Model and Results

# %%
# Save the model
model_path = OUTPUT_DIR / 'final_lstm_model.keras'
lstm_model.save(model_path)
print(f"✅ Model saved to {model_path}")

# Save results and metrics
results = {
    'model_type': 'LSTM',
    'sequence_length': sequence_length,
    'n_features': n_features,
    'feature_names': available_realistic,
    'total_parameters': total_params,
    'training_time': training_time,
    'epochs_trained': len(history.history['loss']),
    'metrics': {
        'train': lstm_train_metrics,
        'val': lstm_val_metrics,
        'test': lstm_test_metrics
    },
    'history': history.history
}

results_path = OUTPUT_DIR / 'lstm_results.pkl'
with open(results_path, 'wb') as f:
    pickle.dump(results, f)
print(f"✅ Results saved to {results_path}")

print("\n✨ LSTM training notebook completed successfully!")
# Out:
# ✅ Model saved to processed_data/final_lstm_model.keras
# ✅ Results saved to processed_data/lstm_results.pkl
#
# ✨ LSTM training notebook completed successfully!
